# %%
pip install PyPDF2

# %%
import os
import re
import json
from PyPDF2 import PdfReader

# ✅ Define folder paths
FOLDER_PATHS = {
    'Depression': './Depression & Anxiety',
    'Personality & Behaviour': './Personality & Behaviour Analysis',
    'Stress & Coping': './Stress & Coping Mechanisms',
    'Trauma & PTSD': './Trauma & PTSD'
}

# ✅ Extract text from PDF
def extract_text_from_pdf(file_path):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() or ""
    return text

# ✅ Advanced line-wise question grouping
def extract_lines_as_questions(text):
    lines = [line.strip() for line in text.strip().split('\n') if line.strip()]
    return lines

# ✅ Extract structured questions from folder
def extract_questions_from_folder(folder_path):
    question_set = set()
    for file in os.listdir(folder_path):
        if file.endswith('.pdf'):
            file_path = os.path.join(folder_path, file)
            try:
                print(f"📄 Processing {file_path}...")
                text = extract_text_from_pdf(file_path)
                lines = extract_lines_as_questions(text)
                question_set.update(lines)
            except Exception as e:
                print(f"❌ Error reading {file_path}: {e}")
    return sorted(list(question_set))

# ✅ Extract and structure all category questions
all_category_questions = {}

for category, path in FOLDER_PATHS.items():
    if os.path.exists(path):
        print(f"\n🔎 Extracting lines for {category}...")
        extracted_lines = extract_questions_from_folder(path)
        if extracted_lines:
            all_category_questions[category] = [{
                "questions": extracted_lines
            }]
        else:
            print(f"⚠️ No questions found in {category}")
    else:
        print(f"❌ Folder not found: {path}")

# ✅ Display example
print("\n📝 Preview of extracted content:")
for category, blocks in all_category_questions.items():
    print(f"\n--- {category} ---")
    for i, q in enumerate(blocks[0]["questions"][:10], 1):  # Preview first 10
        print(f"{i}. {q}")
    print("..." + "-" * 30)

# ✅ Save to JSON file
with open('questions.json', 'w', encoding='utf-8') as f:
    json.dump(all_category_questions, f, indent=4, ensure_ascii=False)

print("\n✅ Structured questions saved to 'questions.json'")
# Out:
# 🔎 Extracting lines for Depression...
# 📄 Processing ./Depression & Anxiety\Beck Anxiety Inventory (BAI) – Measures anxiety levels..pdf...
# 📄 Processing ./Depression & Anxiety\Beck-Depression-Inventory-BDI(self reported test for depression symptoms).pdf...
# 📄 Processing ./Depression & Anxiety\GAD-7_Anxiety-updated_0(Assesses anxiety levels.).pdf...
# 📄 Processing ./Depression & Anxiety\HAMILTON-DEPRESSION(Used for clinical depression assessment.).pdf...
# 📄 Processing ./Depression & Anxiety\PHQ9 id date 08.03(to measure severity of dpession).pdf...
#
# 🔎 Extracting lines for Personality & Behaviour...
# 📄 Processing ./Personality & Behaviour Analysis\MBTI-Personality-Type-Test.pdf...
# 📄 Processing ./Personality & Behaviour Analysis\MMPI-2-Test-Questions.pdf...
#
# 🔎 Extracting lines for Stress & Coping...
# 📄 Processing ./Stress & Coping Mechanisms\COPE Inventory – Assesses different coping styles (e.g., avoidance, problem-solving)..pdf...
# 📄 Processing ./Stress & Coping Mechanisms\Perceived Stress Scale (PSS) – Measures perceived stress levels..pdf...
#
# 🔎 Extracting lines for Trauma & PTSD...
# 📄 Processing ./Trauma & PTSD\ACE (Adverse Childhood Experiences Questionnaire).pdf...
# 📄 Processing ./Trauma & PTSD\PCL-5 (PTSD Checklist) – Evaluates PTSD symptoms..pdf...
#
# 📝 Preview of extracted content:
#
# --- Depression ---
# 1. (positions 0 through 4).3 SUICIDE
# 2. - if there are 2-4 3s in the shaded section (one of which corresponds to Question #1 or #2)
# 3. - if there are at least 5 3s in the shaded section (one of which corresponds to Question #1 or #2)
# 4. 0
# 5. 0   I am no more irritated by things than I ever was.        1   I am slightly more irritated now than usual.
# 6. 0   I am no more worri ed about my health than usual.
# 7. 0  I am not particularly discouraged about the future. 1
# 8. 0  I do not feel sad.
# 9. 0 1 2 3Feeling bad about yourself   or that you are a failure or
# 10. 0 1 2 3Feeling down, depressed, or hopeless 2.
# ...------------------------------
#
# --- Personality & Behaviour ---
# 1.  A broadening of their own ambitions which includes rather than excludes others from the decision
# 2.  A competitive flair which drives them to win out in difficult situations. ESTP’s love to have the
# 3.  A detailed and finely nuanced appreciation of the outside world.
# 4.  A flair for dramatic illustration and story telling which makes them excellent teachers of the young
# 5.  A great ability to understand the objective world, its facts and realities.
# 6.  A great talent for reading people and knowing “where they’re at” by just watching their behavior
# 7.  A knack for showing not only how certain things can be done, but how they can be done in a far
# 8.  A lack of sensitivity to the feelings and ways of those who might need reassurance, security or
# 9.  A mental toughness which makes them extremely hard to beat. In any contest, the ESTP will
# 10.  A propensity for leadership which follows naturally from their ability to control and manage real
# ...------------------------------
#
# --- Stress & Coping ---
# 1. !Lying down in the afternoon
# 2. !Sitting and reading
# 3. !Sitting and talking to someone
# 4. !Watching TV
# 5. 'Sitting inactive in a public place
# 6. ( e) it doesn 't apply to you.
# 7. (0) (1) (2) (3)
# 8. (1) (2) (3)
# 9. (1) (2) (3) (4) (5)
# 10. (4)
# ...------------------------------
#
# --- Trauma & PTSD ---
# 1. (for example, people, places, conversations, activities,objects, or situations)? 0 1 2 3 4
# 2. **Exceptions:  Due to the natur e of some levels of care and program types, there are circumstanc es in which
# 3. *Note:  This questionnaire should only be given to adults ages 18 and older; it should not be given to children or
# 4. 1. Did a parent or oth er adult in the household often :
# 5. 1. Natural disaster (for example, flood, hurricane ,
# 6. 1. Repeated, disturbing, and unwanted memories of the
# 7. 10. Blaming yourself or someone else for the stressful
# 8. 10. Combat or exposure to a war-zone (in the militar y or
# 9. 10. Did a household member go to prison?
# 10. 11. Captivity (for example, being kidnapped, abducted ,
# ...------------------------------
#
# ✅ Structured questions saved to 'questions.json'
